# %% [markdown]
# # Lab 02 - Multi-Objective Optimization
# ## Tasks
# - Learn to solve optimization problems using the Xopt package
# - Conduct multi-objective optimization on AWA photoinjector example

# %% [markdown]
# ## Set up environment

# %%
# !pip install xopt==2.5.2
# !pip install pygmo
# Out:
# Requirement already satisfied: xopt==2.5.2 in /usr/local/lib/python3.11/dist-packages (2.5.2)
# Requirement already satisfied: deap in /usr/local/lib/python3.11/dist-packages (from xopt==2.5.2) (1.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xopt==2.5.2) (1.26.4)
# Requirement already satisfied: pydantic>=2.3 in /usr/local/lib/python3.11/dist-packages (from xopt==2.5.2) (2.10.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from xopt==2.5.2) (6.0.2)
# Requirement already satisfied: botorch>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from xopt==2.5.2) (0.13.0)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.11/dist-packages (from xopt==2.5.2) (1.13.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from xopt==2.5.2) (2.2.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from xopt==2.5.2) (7.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from xopt==2.5.2) (4.67.1)
# Requirement already satisfied: orjson in /usr/local/lib/python3.11/dist-packages (from xopt==2.5.2) (3.10.15)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from xopt==2.5.2) (3.10.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from botorch>=0.12.0->xopt==2.5.2) (4.12.2)
# Requirement already satisfied: pyre_extensions in /usr/local/lib/python3.11/dist-packages (from botorch>=0.12.0->xopt==2.5.2) (0.0.32)
# Requirement already satisfied: gpytorch==1.14 in /usr/local/lib/python3.11/dist-packages (from botorch>=0.12.0->xopt==2.5.2) (1.14)
# Requirement already satisfied: linear_operator==0.6 in /usr/local/lib/python3.11/dist-packages (from botorch>=0.12.0->xopt==2.5.2) (0.6)
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from botorch>=0.12.0->xopt==2.5.2) (2.5.1+cu124)
# Requirement already satisfied: pyro-ppl>=1.8.4 in /usr/local/lib/python3.11/dist-packages (from botorch>=0.12.0->xopt==2.5.2) (1.9.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.11/dist-packages (from botorch>=0.12.0->xopt==2.5.2) (1.0.0)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.11/dist-packages (from botorch>=0.12.0->xopt==2.5.2) (3.5.0)
# Requirement already satisfied: jaxtyping in /usr/local/lib/python3.11/dist-packages (from gpytorch==1.14->botorch>=0.12.0->xopt==2.5.2) (0.2.37)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /usr/local/lib/python3.11/dist-packages (from gpytorch==1.14->botorch>=0.12.0->xopt==2.5.2) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from gpytorch==1.14->botorch>=0.12.0->xopt==2.5.2) (1.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.3->xopt==2.5.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.3->xopt==2.5.2) (2.27.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->xopt==2.5.2) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->xopt==2.5.2) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->xopt==2.5.2) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->xopt==2.5.2) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->xopt==2.5.2) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->xopt==2.5.2) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->xopt==2.5.2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->xopt==2.5.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->xopt==2.5.2) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->xopt==2.5.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->xopt==2.5.2) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->xopt==2.5.2) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->xopt==2.5.2) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->xopt==2.5.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->xopt==2.5.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->xopt==2.5.2) (2025.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->xopt==2.5.2) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->xopt==2.5.2) (6.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->xopt==2.5.2) (4.9.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from pyro-ppl>=1.8.4->botorch>=0.12.0->xopt==2.5.2) (3.4.0)
# Requirement already satisfied: pyro-api>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from pyro-ppl>=1.8.4->botorch>=0.12.0->xopt==2.5.2) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->xopt==2.5.2) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (1.13.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (6.5.5)
# Requirement already satisfied: typing-inspect in /usr/local/lib/python3.11/dist-packages (from pyre_extensions->botorch>=0.12.0->xopt==2.5.2) (0.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->xopt==2.5.2) (0.8.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->xopt==2.5.2) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->xopt==2.5.2) (0.2.13)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from jaxtyping->gpytorch==1.14->botorch>=0.12.0->xopt==2.5.2) (0.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.1->botorch>=0.12.0->xopt==2.5.2) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->gpytorch==1.14->botorch>=0.12.0->xopt==2.5.2) (1.4.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect->pyre_extensions->botorch>=0.12.0->xopt==2.5.2) (1.0.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (3.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (0.22.3)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->xopt==2.5.2) (1.3.1)
# Requirement already satisfied: pygmo in /usr/local/lib/python3.11/dist-packages (2.19.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pygmo) (1.26.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from pygmo) (3.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pygmo) (1.13.1)

# %%
# %reset -f
from google.colab import drive
import os

drive.mount('/content/drive')
path = '/content/drive/MyDrive/optimization_and_ml/labs/lab_02_multi_objective_optimization'
os.chdir(path)
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# awa_model.pt  Figure5.png  lab_02.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt
import xopt

import torch
from pandas import DataFrame as df
from pygmo import fast_non_dominated_sorting, hypervolume


os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# # Multi-objective optimization of a test problem

# %% [markdown]
# Our goal is to find the ideal trade-off between two objectives $f_1,f_2$. We will use a problem selected from a collection of test problems known as the ZDT problem suite. The following explaination is from (https://github.com/anyoptimization/pymoo/blob/main/docs/source/problems/multi/zdt.ipynb) which discusses the entire collection.
#
# ### ZDT
#
# The ZDT <cite data-cite="zdt"></cite> problem suite is based on the construction process
#
# \begin{align}
# \begin{split}
# \min && \; f_1(x)\\
# \min && \; f_2(x) = g(x) \, h(f_1(x),g(x))
# \end{split}
# \end{align}
#
# where two objective have to be minimized. The function $g(x)$ can be considered as the function for convergenece  and usually $g(x) = 1$ holds for pareto-optimal solutions (except for ZDT5).
#
# ### ZDT1
#
# This is a n-D variable problem (here we will use $n=10$) with a convex Pareto-optimal set:
#
# **Definition**
#
# \begin{align}
# \begin{split}
# f_1(x) &= \, & x_1 \\
# g(x) &=& 1 + \frac{9}{n-1} \; \sum_{i=2}^{n} x_i \\
# h(f_1,g) &=& 1 - \sqrt{f_1/g} \\
# \end{split}
# \end{align}
#
#
# $$0 \leq x_i \leq 1 \quad i=1,\ldots,n$$
#
# **Optimum**
#
# $$0 \leq x_1^* \leq 1  \quad \text{and} \quad x_i^*=0 \; \text{for} \; i=2,\ldots,n$$

# %% [markdown]
# To solve this problem we will use the evolutionary CNSGA algorithm, implmented in Xopt.

# %% [markdown]
# ## Defining the problem in Xopt
#
# Xopt can interface with arbitrary evaluate functions (defined in Python) with the
# following form:
# ```python
# def evaluate(inputs: dict) -> dict:
#     """ your code here """
# ```
# Evaluate functions must accept a dictionary object that **at least** has the keys
# specified in `variables, constants` and returns a dictionary
# containing **at least** the
# keys contained in `objectives, constraints`. Extra dictionary keys are tracked and
# used in the evaluate function but are not modified by xopt.

# %%
from xopt import Evaluator

# define the problem as a python callable
n_dims = 10
def evaluate(input_dict):
    x = np.array([input_dict[f"x{i + 1}"] for i in range(n_dims)])

    f1 = x[0]
    g = 1 + (9 / (n_dims - 1)) * np.sum(x[1:])
    h = 1 - np.sqrt(f1 / g)
    f2 = g * h

    return {"f1": f1, "f2": f2, "g": g}

evaluator = Evaluator(function=evaluate)

# %% [markdown]
# ## Define the variables and objectives
# Next we define the variables and objectives for our problem in a `VOCS` object.

# %%
from xopt import VOCS
vocs = VOCS(
    variables={f"x{i + 1}": [0, 1] for i in range(n_dims)},
    objectives={"f1": "MINIMIZE", "f2": "MINIMIZE"},
)
vocs.model_dump()
# Out:
# {'variables': {'x1': [0.0, 1.0],
#   'x2': [0.0, 1.0],
#   'x3': [0.0, 1.0],
#   'x4': [0.0, 1.0],
#   'x5': [0.0, 1.0],
#   'x6': [0.0, 1.0],
#   'x7': [0.0, 1.0],
#   'x8': [0.0, 1.0],
#   'x9': [0.0, 1.0],
#   'x10': [0.0, 1.0]},
#  'constraints': {},
#  'objectives': {'f1': 'MINIMIZE', 'f2': 'MINIMIZE'},
#  'constants': {},
#  'observables': []}

# %% [markdown]
# ## Define the optimization algorithm

# %%
from xopt.generators.ga import CNSGAGenerator
generator = CNSGAGenerator(
    vocs=vocs,
    population_size=64,
    crossover_probability=0.75,
    mutation_probability=0.25
)
generator.model_dump()
# Out:
# {'population_size': 64,
#  'crossover_probability': 0.75,
#  'mutation_probability': 0.25,
#  'population_file': None,
#  'output_path': None,
#  'population': None}

# %% [markdown]
# ## Combine the evaluator, vocs, and generator objects into the Xopt object

# %%
from xopt import Xopt
X = Xopt(
    vocs=vocs,
    generator=generator,
    evaluator=evaluator
)

# %%
generations = 100
for _ in range(64 * generations):
    X.step()

# %%
X.data.plot.scatter(x="f1",y="f2",c=X.data.index,cmap="viridis")
# Out:
# <Axes: xlabel='f1', ylabel='f2'>

# %% [markdown]
# > ### **Task**
# > Plot the Pareto front and calculate the front hypervolume with the reference point (11,11). See `fast_non_dominated_sorting` in https://esa.github.io/pygmo2/tutorials/moo.html and `hypervolume` in https://esa.github.io/pygmo2/tutorials/hypervolume.html .

# %%
X.data.head()
# Out:
#          x1        x2        x3        x4        x5        x6        x7  \
# 0  0.221665  0.792948  0.853840  0.293493  0.352412  0.727793  0.188799
# 1  0.854557  0.497855  0.378276  0.456476  0.391018  0.830839  0.804296
# 2  0.838076  0.922519  0.896711  0.611356  0.406850  0.127040  0.087302
# 3  0.331633  0.382788  0.032901  0.278939  0.566153  0.924229  0.046412
# 4  0.033960  0.624449  0.129405  0.702981  0.891809  0.517662  0.258670
#
#          x8        x9       x10        f1        f2         g  xopt_runtime  \
# 0  0.931821  0.872900  0.172739  0.221665  5.015686  6.186747      0.000229
# 1  0.090386  0.879461  0.421009  0.854557  3.533001  5.749614      0.000087
# 2  0.593921  0.775582  0.348374  0.838076  3.570699  5.769654      0.000061
# 3  0.713216  0.439233  0.855680  0.331633  3.921367  5.239549      0.000065
# 4  0.805734  0.742902  0.582012  0.033960  5.794713  6.255623      0.000070
#
#    xopt_error
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
ndf, *_ = fast_non_dominated_sorting(X.data[["f1", "f2"]])

# %%
plt.figure()
plt.scatter(X.data["f1"][ndf[0]], X.data["f2"][ndf[0]])
plt.xlabel("f1")
plt.xlabel("f2")
plt.show()

# %%
hypervolume(X.data[["f1", "f2"]].iloc[ndf[0]].to_numpy()).compute([11, 11])
# Out:
# 120.61453318779353

# %% [markdown]
# # Multi-objective optimization of the AWA photoinjector

# %% [markdown]
# Here we will find the pareto front of the AWA photoinjector problem (see below).
# Input variables are shown in red and output variables are shown in blue. Both the
# inputs and outputs are normalized to [-1,1]. Our goal is to minimize all of the
# output beam parameters. To model the AWA beamline dynamics we use a pre-compiled, fast
# executing neural network surrogate model (that you will have a chance to build in lab
#  5!). The inputs to this model are `[P0, P1, G0, G1, K1, K2]` and the outputs are
#  `[rms_x, rms_y, rms_s, emit_x, emit_y, emit_s, dE]`.
#
#
#
# ![Figure5.png](data:image/png;base64,...)

# %%
# get AWA model
awa_model = torch.jit.load("awa_model.pt")

# test awa_model
x = torch.rand(6)
awa_model(x)
# Out:
# tensor([-0.8273, -0.8092, -0.5610, -0.7341, -0.7207, -0.7449,  0.0331],
#        grad_fn=<TanhBackward0>)

# %%
# define variables and objectives in VOCS object
from xopt import VOCS
awa_vocs = VOCS(
    variables={
        'P0':[-1.0,1.0],
        'P1':[-1.0,1.0],
        'G0':[-1.0,1.0],
        'G1':[-1.0,1.0],
        'K1':[-1.0,1.0],
        'K2':[-1.0,1.0]
    },
    objectives={
        'rms_x':"MINIMIZE",
        'rms_y':"MINIMIZE",
        'rms_s':"MINIMIZE",
        'emit_x':"MINIMIZE",
        'emit_y':"MINIMIZE",
        'emit_s':"MINIMIZE",
        'dE':"MINIMIZE"
    }
)

# %% [markdown]
# > ### **Task**
# > Use the above code to find the 7D pareto front of the AWA multi-objective problem. Plot the front projected onto the bunch length vs. horizontal emittance subspace.
#
# > Note: when evaluating the NN model, you should call `detach().numpy()` to convert the output of the model into a numpy array.

# %%
from xopt import Evaluator

def evaluate(inputs: dict) -> dict:
  X = torch.tensor(list(inputs.values()))
  Y = awa_model(X).detach().numpy()
  objectives={
        'rms_x': Y[0],
        'rms_y': Y[1],
        'rms_s': Y[2],
        'emit_x': Y[3],
        'emit_y': Y[4],
        'emit_s': Y[5],
        'dE': Y[6]}
  return objectives

evaluator = Evaluator(function=evaluate)

# %%
from xopt.generators.ga import CNSGAGenerator

generator = CNSGAGenerator(
    vocs=awa_vocs,
    population_size=64,
    crossover_probability=0.75,
    mutation_probability=0.25
)
generator.model_dump()
# Out:
# {'population_size': 64,
#  'crossover_probability': 0.75,
#  'mutation_probability': 0.25,
#  'population_file': None,
#  'output_path': None,
#  'population': None}

# %%
from xopt import Xopt
X = Xopt(
    vocs=awa_vocs,
    generator=generator,
    evaluator=evaluator
)

# %%
generations = 100
for _ in range(64 * generations):
    X.step()

# %%
awa_ndf, *_ = fast_non_dominated_sorting(X.data[X.vocs.objective_names])

# %%
plt.figure()
plt.scatter(X.data["rms_s"][awa_ndf[0]], X.data["emit_x"][awa_ndf[0]])
plt.xlabel("rms_s")
plt.ylabel("emit_s")
plt.show()

# %% [markdown]
# # **Homework**
# Another approach to solving multi-objective problems is to specify explicit weights that rate the relative importance of each objective. In this case the problem is single objective and can be solved by a variety of single objective algorithms, including RCDS. Use the Xopt `RCDSGenerator` generator (see https://xopt.xopt.org/examples/rcds/rcds/ for an example) to solve for multiple different objective trade-offs of the ZDT1 problem
# - even weighting between all objectives
# - weight `f1 = 2*f2` with all others equal weighting with respect to rms_s
# - weight `f2 = 2*f1` with all others equal weighting with respect to rms_s
#
# Plot the `f1,f2` function values found to minimize the three problems on an axis that also contains the ZDT1 pareto front. How do these solutions compare to the Pareto front in objective space?

# %% [markdown]
# ## Defining the problem in Xopt

# %%
from functools import partial

# %%
from xopt import Evaluator

# define the problem as a python callable
n_dims = 10
# Multi objective ZDT problem
def evaluate(input_dict):
    x = np.array([input_dict[f"x{i + 1}"] for i in range(n_dims)])

    f1 = x[0]
    g = 1 + (9 / (n_dims - 1)) * np.sum(x[1:])
    h = 1 - np.sqrt(f1 / g)
    f2 = g * h

    return {"f1": f1, "f2": f2, "even": f1 + f2, "2f1": 2*f1 + f2, "2f2": f1 + 2*f2}
evaluator = Evaluator(function=evaluate)
# evaluator_even = Evaluator(function=partial(scalar_evaluate, 1, 1))
# evaluator_2f2 = Evaluator(function=partial(scalar_evaluate, 1, 2))
# evaluator_2f1 = Evaluator(function=partial(scalar_evaluate, 2, 1))

# %% [markdown]
# ## Define the variables and objectives
# Next we define the variables and objectives for our problem in a `VOCS` object.

# %%
from xopt import VOCS

vocs_even = VOCS(
    variables={f"x{i + 1}": [0, 1] for i in range(n_dims)},
    objectives={"even": "MINIMIZE"},
)

vocs_2f1 = VOCS(
    variables={f"x{i + 1}": [0, 1] for i in range(n_dims)},
    objectives={"2f1": "MINIMIZE"},
)

vocs_2f2 = VOCS(
    variables={f"x{i + 1}": [0, 1] for i in range(n_dims)},
    objectives={"2f2": "MINIMIZE"},
)

# %% [markdown]
# ## Define the optimization algorithm

# %%
from xopt.generators.rcds.rcds import RCDSGenerator
generator = RCDSGenerator(
    vocs=vocs_even
)
generator_2f1 = RCDSGenerator(
    vocs=vocs_2f1
)
generator_2f2 = RCDSGenerator(
    vocs=vocs_2f2
)

# %% [markdown]
# ## Combine the evaluator, vocs, and generator objects into the Xopt object

# %%
from xopt import Xopt
X_even = Xopt(
    vocs=vocs_even,
    generator=generator,
    evaluator=evaluator
)
X_2f2 = Xopt(
    vocs=vocs_2f2,
    generator=generator,
    evaluator=evaluator
)
X_2f1 = Xopt(
    vocs=vocs_2f1,
    generator=generator,
    evaluator=evaluator
)

iterations = 10000
for _ in range(iterations):
    X_even.step()
    X_2f1.step()
    X_2f2.step()

# %%
objs_even = X_even.data[["f1", "f2"]]
objs_2f2 = X_2f2.data[["f1", "f2"]]
objs_2f1 = X_2f1.data[["f1", "f2"]]

# %%
plt.figure()
plt.scatter(
    x=objs_even["f1"], y=objs_even["f2"],
    edgecolors="C0", facecolors="None",
    label="even weigths", alpha=0.5)
plt.scatter(
    x=objs_2f2["f1"], y=objs_2f2["f2"],
    edgecolors="C1", facecolors="None",
    label="f = f1 + 2f2", alpha=0.5)
plt.scatter(
    x=objs_2f1["f1"], y=objs_2f1["f2"],
    edgecolors="C2", facecolors="None",
    label="f = 2f2 + f1", alpha=0.5)
plt.scatter(
    X.data["f1"][ndf[0]], X.data["f2"][ndf[0]],
    edgecolors="k", facecolors="None",
    label="CNSGA Pareto Front")

plt.scatter(
    x=objs_even["f1"].iloc[-1], y=objs_even["f2"].iloc[-1],
    label="even weigths solution")

plt.scatter(
    x=objs_2f2["f1"].iloc[-1], y=objs_2f2["f2"].iloc[-1],
    label="f = f1 + 2f2 solution")

plt.scatter(
    x=objs_2f1["f1"].iloc[-1], y=objs_2f1["f2"].iloc[-1],
    label="f = 2f2 + f1 solution")
plt.xlabel("f1")
plt.ylabel("f2")
plt.legend()
plt.show()

# %% [markdown]
# The RCDS scalarized solutions found are quite comparable to the multi-objective optimized Pareto front, in fact the three of them lied at the front. However, I noticed it was quite difficult to reach this result. Most times the optimization procedure seemed very unstable, rendering wildy different scenarios depending on the different trials. Maybe ZDT using RCDS is quite difficult dpeneding on where the optimization starts.
